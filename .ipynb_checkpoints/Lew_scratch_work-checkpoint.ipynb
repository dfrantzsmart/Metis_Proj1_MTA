# %%
import sys
print("Python Version:", sys.version)

import statistics
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from datetime import datetime
pd.set_option('display.max_rows', 500)
# %config InlineBackend.figure_format = 'svg'
# %matplotlib inline
# Out:
# Python Version: 3.7.6 (default, Jan  8 2020, 13:42:34)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
# yymmdd format
dates = ['190803',
        '190810',
        '190817',
        '190824',
        '190831',
        '190907',
        '190914',
        '190921',
        '190928']

# iterate through dates and pull in csv and cat dataframes together
df_turns = []
for date in dates:
    df_turns.append(pd.read_csv('http://web.mta.info/developers/data/nyct/turnstile/turnstile_'+date+'.txt'))

# %%
# Concat all dataframes
df_turns = pd.concat(df_turns)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-6-c99b20c0f7b7> in <module>
#       1 # Concat all dataframes
# ----> 2 df_turns = pd.concat(df_turns)
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     279         verify_integrity=verify_integrity,
#     280         copy=copy,
# --> 281         sort=sort,
#     282     )
#     283
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/reshape/concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     307                 "first argument must be an iterable of pandas "
#     308                 "objects, you passed an object of type "
# --> 309                 '"{name}"'.format(name=type(objs).__name__)
#     310             )
#     311
#
# TypeError: first argument must be an iterable of pandas objects, you passed an object of type "DataFrame"

# %%
#Clean up column names
new_col_names = [name.strip() for name in df_turns.columns]
df_turns.columns = new_col_names

# %%
#Let's have a quick look at 'DESC'
df_turns['DESC'].value_counts()

# %%
# Audit rows (RECOVR AUD) make up about 0.4% of rows
# Remove audited rows since many are duplicates

df_turns=df_turns[df_turns.DESC!='RECOVR AUD']

# Remove column now that all are regular

del df_turns['DESC']

# %%
df_turns.head()

# %%
# Create a DateTime column that can be used for timeseries
df_turns.loc[:,'DATETIME'] = pd.to_datetime(df_turns['DATE'] + ' ' + df_turns['TIME'])

#Convert Date column to proper date type.
df_turns['DATE']  = pd.to_datetime(df_turns['DATE'],format='%m/%d/%Y')

#convert time to datetime type
df_turns['TIME']=pd.to_datetime(df_turns['TIME'], format='%H:%M:%S')

# %%
df_turns.head(10)
# Out:
#     C/A  UNIT       SCP STATION LINENAME DIVISION       DATE  \
# 0  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 1  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 2  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 3  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 4  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 5  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-27
# 6  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-28
# 7  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-28
# 8  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-28
# 9  A002  R051  02-00-00   59 ST  NQR456W      BMT 2019-07-28
#
#                  TIME  ENTRIES    EXITS            DATETIME
# 0 1900-01-01 00:00:00  7148288  2418935 2019-07-27 00:00:00
# 1 1900-01-01 04:00:00  7148306  2418939 2019-07-27 04:00:00
# 2 1900-01-01 08:00:00  7148326  2418975 2019-07-27 08:00:00
# 3 1900-01-01 12:00:00  7148441  2419042 2019-07-27 12:00:00
# 4 1900-01-01 16:00:00  7148647  2419101 2019-07-27 16:00:00
# 5 1900-01-01 20:00:00  7148908  2419145 2019-07-27 20:00:00
# 6 1900-01-01 00:00:00  7149087  2419165 2019-07-28 00:00:00
# 7 1900-01-01 04:00:00  7149111  2419171 2019-07-28 04:00:00
# 8 1900-01-01 08:00:00  7149126  2419198 2019-07-28 08:00:00
# 9 1900-01-01 12:00:00  7149198  2419241 2019-07-28 12:00:00

# %%
#backup
df_backup=df_turns.copy()

# %%
#Sort in order of datetime
df_turns = df_turns.sort_values(by=['DATETIME']).reset_index()

# %%
# Caluclate Entries Aggregated at station level by DateTime
df_turns['Entry_Diff']=df_turns.groupby(['STATION', 'C/A', 'UNIT', 'SCP'],as_index=False)['ENTRIES'].transform(pd.Series.diff)['ENTRIES']

# Caluclate Exits Aggregated at station level by DateTime
df_turns['Exit_Diff']=df_turns.groupby(['STATION', 'C/A', 'UNIT', 'SCP'],as_index=False)['EXITS'].transform(pd.Series.diff)['EXITS']

# %%
#Absolute Value to deal with counting backward issues 
df_turns['Entry_Diff'] = abs(df_turns['Entry_Diff'])
df_turns['Exit_Diff']=abs(df_turns['Exit_Diff'])

# Calculate both
df_turns['Total_Traffic']=df_turns['Entry_Diff']+df_turns['Exit_Diff']

# %%
#Drop NaN Values

df_turns.dropna().head()
# Out:
#        index    C/A  UNIT       SCP         STATION LINENAME DIVISION  \
# 2554  118307  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2592  118308  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2636  118309  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2640  118310  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 4489  118311  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
#
#            DATE                TIME  ENTRIES  EXITS            DATETIME  \
# 2554 2019-07-27 1900-01-01 00:24:57       65     30 2019-07-27 00:24:57
# 2592 2019-07-27 1900-01-01 00:38:57       65     30 2019-07-27 00:38:57
# 2636 2019-07-27 1900-01-01 00:52:57       65     30 2019-07-27 00:52:57
# 2640 2019-07-27 1900-01-01 00:56:25     4043   3513 2019-07-27 00:56:25
# 4489 2019-07-27 1900-01-01 01:06:57       65     30 2019-07-27 01:06:57
#
#       Entry_Diff  Exit_Diff  Total_Traffic
# 2554         2.0        0.0            2.0
# 2592         0.0        0.0            0.0
# 2636         0.0        0.0            0.0
# 2640      3978.0     3483.0         7461.0
# 4489      3978.0     3483.0         7461.0

# %%
# Filter out values in calculated fields outside of upper quartile range
#We want to normalize by these values per station


#df_turns.groupby(['STATION'])['Total_Traffic'].quantile(.99)


q_9 = df_turns['Total_Traffic'].quantile(.99)
df_turns_filt = df_turns[df_turns.Total_Traffic<= q_9]

# %%
#Let's take a look at the busiest stations after our filter operation:
df_per_station = df_turns_filt.groupby(['STATION']).sum()
df_per_station.sort_values('Total_Traffic', ascending = False).head()
# Out:
#                       index        ENTRIES          EXITS  Entry_Diff  \
# STATION
# 34 ST-PENN STA   3401972217  1460365699649  1538055094977   8254361.0
# GRD CNTRL-42 ST  3752729625   919546458460  1105055715021   5679047.0
# 23 ST            2607575657  2091252915203  1812031229789   5750528.0
# FULTON ST        3245309619  1787737426085  1745103246838   5078558.0
# 34 ST-HERALD SQ  1402968886  1646402859827  2064647805215   4784950.0
#
#                  Exit_Diff  Total_Traffic
# STATION
# 34 ST-PENN STA   6992507.0     15246868.0
# GRD CNTRL-42 ST  4802427.0     10481474.0
# 23 ST            4288698.0     10039226.0
# FULTON ST        4419547.0      9498105.0
# 34 ST-HERALD SQ  4558398.0      9343348.0

# %% [markdown]
# --------

# %% [markdown]
# <font size="5">****THIS IS RAMIS PART****

# %%
def Add_Weekday(data_frame, column='Date'):
    dmap = {0:'Mon', 1: 'Tue', 2: 'Wed', 3:'Thu', 4:'Fri', 5:'Sat', 6:'Sun'}
    #Convert column to date
    data_frame[column] = pd.to_datetime(data_frame[column])
    #Add column which shows the Weekday in integer
    data_frame['Day_Number'] = data_frame[column].apply(lambda x: x.dayofweek)
    #Add column which shows the Weekday in words
    data_frame['Weekday'] = data_frame['Day_Number'].map(dmap)
    return data_frame
df_turns_backup2 = df_turns.copy()

# %%
df_turns = Add_Weekday(df_turns,'DATE')
df_turns.head()
# Out:
#     index   C/A  UNIT       SCP         STATION   LINENAME DIVISION  \
# 0       0  A002  R051  02-00-00           59 ST    NQR456W      BMT
# 1  112391  N605  R024  00-05-01  SUTPHIN-ARCHER        EJZ      IND
# 2  112349  N605  R024  00-05-00  SUTPHIN-ARCHER        EJZ      IND
# 3  198692  R612  R057  01-03-03  ATL AV-BARCLAY  BDNQR2345      IRT
# 4  112307  N605  R024  00-00-06  SUTPHIN-ARCHER        EJZ      IND
#
#         DATE       TIME   ENTRIES     EXITS   DATETIME  Entry_Diff  Exit_Diff  \
# 0 2019-07-27 1900-01-01   7148288   2418935 2019-07-27         NaN        NaN
# 1 2019-07-27 1900-01-01         0      1168 2019-07-27         NaN        NaN
# 2 2019-07-27 1900-01-01  33556743  16777216 2019-07-27         NaN        NaN
# 3 2019-07-27 1900-01-01   2120496   1957954 2019-07-27         NaN        NaN
# 4 2019-07-27 1900-01-01   5050187   2146519 2019-07-27         NaN        NaN
#
#    Total_Traffic  Day_Number Weekday
# 0            NaN           5     Sat
# 1            NaN           5     Sat
# 2            NaN           5     Sat
# 3            NaN           5     Sat
# 4            NaN           5     Sat

# %%
#Filter out the Null Values
df_turns.dropna(subset=["Entry_Diff","Exit_Diff",'Total_Traffic'], axis=0, inplace=True)
df_turns.head()
# Out:
#        index    C/A  UNIT       SCP         STATION LINENAME DIVISION  \
# 2554  118307  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2592  118308  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2636  118309  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 2640  118310  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
# 4489  118311  PTH03  R552  00-01-08  JOURNAL SQUARE        1      PTH
#
#            DATE                TIME  ENTRIES  EXITS            DATETIME  \
# 2554 2019-07-27 1900-01-01 00:24:57       65     30 2019-07-27 00:24:57
# 2592 2019-07-27 1900-01-01 00:38:57       65     30 2019-07-27 00:38:57
# 2636 2019-07-27 1900-01-01 00:52:57       65     30 2019-07-27 00:52:57
# 2640 2019-07-27 1900-01-01 00:56:25     4043   3513 2019-07-27 00:56:25
# 4489 2019-07-27 1900-01-01 01:06:57       65     30 2019-07-27 01:06:57
#
#       Entry_Diff  Exit_Diff  Total_Traffic  Day_Number Weekday
# 2554         2.0        0.0            2.0           5     Sat
# 2592         0.0        0.0            0.0           5     Sat
# 2636         0.0        0.0            0.0           5     Sat
# 2640      3978.0     3483.0         7461.0           5     Sat
# 4489      3978.0     3483.0         7461.0           5     Sat

# %%
dfc_grouped = df_turns.groupby(['DATE', 'STATION', 'Weekday'])['Entry_Diff', 'Exit_Diff', 'Total_Traffic'].sum().reset_index()
dfc_grouped.head()
# Out:
# /Users/lewissears/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   """Entry point for launching an IPython kernel.
#         DATE        STATION Weekday  Entry_Diff  Exit_Diff  Total_Traffic
# 0 2019-07-27           1 AV     Sat      4308.0     5146.0         9454.0
# 1 2019-07-27         103 ST     Sat      8648.0     8190.0        16838.0
# 2 2019-07-27  103 ST-CORONA     Sat     11712.0     6833.0        18545.0
# 3 2019-07-27         104 ST     Sat      2040.0      862.0         2902.0
# 4 2019-07-27         110 ST     Sat      5529.0     5140.0        10669.0

# %%
#The upper_quant_df outputs a dataframe of the upper 95% values for each station
upper_quant_df = dfc_grouped.groupby(['STATION'])['Total_Traffic'].quantile([.95]).reset_index()
#Then I merge it with the grouped data 

df_turns_no_outlier = dfc_grouped.merge(upper_quant_df, on='STATION')
df_turns_no_outlier.head()
# Out:
#         DATE STATION Weekday  Entry_Diff  Exit_Diff  Total_Traffic_x  level_1  \
# 0 2019-07-27    1 AV     Sat      4308.0     5146.0           9454.0     0.95
# 1 2019-07-28    1 AV     Sun      4106.0     5309.0           9415.0     0.95
# 2 2019-07-29    1 AV     Mon     14483.0    16525.0          31008.0     0.95
# 3 2019-07-30    1 AV     Tue     16375.0    18206.0          34581.0     0.95
# 4 2019-07-31    1 AV     Wed     16812.0    19777.0          36589.0     0.95
#
#    Total_Traffic_y
# 0          40228.0
# 1          40228.0
# 2          40228.0
# 3          40228.0
# 4          40228.0

# %%
#delete the rows where The difference between Total_Traffic_y and Total_Traffic_x < 0
df_turns_no_outlier['Diff'] = df_turns_no_outlier['Total_Traffic_y'] - df_turns_no_outlier['Total_Traffic_x']
df_turns_no_outlier = df_turns_no_outlier[df_turns_no_outlier['Diff']>= 0]
df_turns_no_outlier = df_turns_no_outlier.sort_values('Weekday')
df_turns_no_outlier[df_turns_no_outlier['STATION']=='FULTON ST']
# Out:
#             DATE    STATION Weekday  Entry_Diff  Exit_Diff  Total_Traffic_x  \
# 14181 2019-08-09  FULTON ST     Fri     94776.0    80917.0         175693.0
# 14174 2019-08-02  FULTON ST     Fri     95880.0    84251.0         180131.0
# 14188 2019-08-16  FULTON ST     Fri     82130.0    61028.0         143158.0
# 14195 2019-08-23  FULTON ST     Fri     88209.0    78941.0         167150.0
# 14202 2019-08-30  FULTON ST     Fri     85186.0    74439.0         159625.0
# 14209 2019-09-06  FULTON ST     Fri    143818.0   218053.0         361871.0
# 14230 2019-09-27  FULTON ST     Fri    101800.0    90237.0         192037.0
# 14223 2019-09-20  FULTON ST     Fri    108503.0    93163.0         201666.0
# 14216 2019-09-13  FULTON ST     Fri    103527.0    90791.0         194318.0
# 14184 2019-08-12  FULTON ST     Mon     91841.0    81610.0         173451.0
# 14219 2019-09-16  FULTON ST     Mon     99713.0    89086.0         188799.0
# 14177 2019-08-05  FULTON ST     Mon     94847.0    84858.0         179705.0
# 14212 2019-09-09  FULTON ST     Mon     99642.0    89043.0         188685.0
# 14205 2019-09-02  FULTON ST     Mon     32714.0    30648.0          63362.0
# 14191 2019-08-19  FULTON ST     Mon     89301.0    80156.0         169457.0
# 14198 2019-08-26  FULTON ST     Mon     86688.0    78655.0         165343.0
# 14226 2019-09-23  FULTON ST     Mon     97641.0    88868.0         186509.0
# 14170 2019-07-29  FULTON ST     Mon     96119.0    84957.0         181076.0
# 14168 2019-07-27  FULTON ST     Sat     37528.0    35038.0          72566.0
# 14224 2019-09-21  FULTON ST     Sat     46000.0    40758.0          86758.0
# 14217 2019-09-14  FULTON ST     Sat     43332.0    39838.0          83170.0
# 14210 2019-09-07  FULTON ST     Sat     47257.0    40949.0          88206.0
# 14203 2019-08-31  FULTON ST     Sat     46543.0    36987.0          83530.0
# 14196 2019-08-24  FULTON ST     Sat     45958.0    40615.0          86573.0
# 14189 2019-08-17  FULTON ST     Sat     48135.0    41500.0          89635.0
# 14182 2019-08-10  FULTON ST     Sat     43451.0    38709.0          82160.0
# 14175 2019-08-03  FULTON ST     Sat     43102.0    37552.0          80654.0
# 14170     0.95         507437.0  326361.0
# 14168     0.95         507437.0  434871.0
# 14224     0.95         507437.0  420679.0
# 14217     0.95         507437.0  424267.0
# 14210     0.95         507437.0  419231.0
# 14203     0.95         507437.0  423907.0
# 14196     0.95         507437.0  420864.0
# 14189     0.95         507437.0  417802.0
# 14182     0.95         507437.0  425277.0
# 14175     0.95         507437.0  426783.0
# 14169     0.95         507437.0  441336.0
# 14176     0.95         507437.0  441687.0
# 14183     0.95         507437.0  440850.0
# 14225     0.95         507437.0  442397.0
# 14218     0.95         507437.0  439200.0
# 14204     0.95         507437.0  432767.0
# 14190     0.95         507437.0  434231.0
# 14229     0.95         507437.0  305705.0
# 14222     0.95         507437.0  306633.0
# 14173     0.95         507437.0  314061.0
# 14180     0.95         507437.0  313923.0
# 14187     0.95         507437.0  321616.0
# 14194     0.95         507437.0  327047.0
# 14201     0.95         507437.0  327113.0
# 14208     0.95         507437.0  310588.0
# 14215     0.95         507437.0  303560.0
# 14185     0.95         507437.0  325265.0
# 14171     0.95         507437.0  216643.0
# 14192     0.95         507437.0  325647.0
# 14227     0.95         507437.0  300727.0
# 14213     0.95         507437.0  308959.0
# 14206     0.95         507437.0  326592.0
# 14199     0.95         507437.0  326411.0
# 14228     0.95         507437.0  305081.0
# 14221     0.95         507437.0  306735.0
# 14214     0.95         507437.0  300846.0
# 14207     0.95         507437.0  318660.0
# 14200     0.95         507437.0  327869.0
# 14193     0.95         507437.0  328277.0
# 14186     0.95         507437.0  322912.0
# 14179     0.95         507437.0  317831.0
# 14172     0.95         507437.0  316817.0

# %% [markdown]
# -------------

# %% [markdown]
# **Only Analysis on Street Canvassing:** "It's Better to look for a neightborhood during lunch and evening hours. A heavy concentration of restaurants and bars where people are wandering and waiting for a table is usually a good bet."

# %% [markdown]
# <font size="5">**Weekdays**

# %%
df_max_no_outlier = df_turns_no_outlier.groupby(['STATION']).sum()

# %%
#Make a DataFrame that is simply Station/Weekday/Traffic
df_reduce = df_turns_no_outlier[['DATE','STATION','Weekday','Total_Traffic_x']].copy()
df_reduce['TRAFFIC'] = df_reduce['Total_Traffic_x']
df_reduce = df_reduce.drop(['Total_Traffic_x'], axis = 1)
df_reduce_grouped = df_reduce.groupby(['STATION', 'Weekday'])['TRAFFIC'].mean().reset_index()
df_reduce_grouped.head(10)
# Out:
#   STATION Weekday       TRAFFIC
# 0    1 AV     Fri  35681.833333
# 1    1 AV     Mon  29466.000000
# 2    1 AV     Sat  13435.111111
# 3    1 AV     Sun   9933.666667
# 4    1 AV     Thu  36339.875000
# 5    1 AV     Tue  34532.777778
# 6    1 AV     Wed  36531.000000
# 7  103 ST     Fri  49484.333333
# 8  103 ST     Mon  44940.222222
# 9  103 ST     Sat  29862.000000

# %%
#Create Week and Weekend Buckets

def daytype(day):
    if day == 'Sat' or day == 'Sun':
        return 'Weekend'
    else:
        return 'Weekday'

df_reduce_grouped['Day_Type'] = df_reduce_grouped['Weekday'].apply(daytype)
df_reduce_grouped
# Out:
#         STATION Weekday       TRAFFIC Day_Type
# 0          1 AV     Fri  35681.833333  Weekday
# 1          1 AV     Mon  29466.000000  Weekday
# 2          1 AV     Sat  13435.111111  Weekend
# 3          1 AV     Sun   9933.666667  Weekend
# 4          1 AV     Thu  36339.875000  Weekday
# ...         ...     ...           ...      ...
# 2641  ZEREGA AV     Sat   2390.777778  Weekend
# 2642  ZEREGA AV     Sun   1887.444444  Weekend
# 2643  ZEREGA AV     Thu   5228.111111  Weekday
# 2644  ZEREGA AV     Tue   5015.714286  Weekday
# 2645  ZEREGA AV     Wed   4977.142857  Weekday
#
# [2646 rows x 4 columns]

# %%
df_reduce_grouped_day_type = df_reduce_grouped.groupby(['STATION','Day_Type'])['TRAFFIC'].mean().reset_index()
df_reduce_grouped_day_type.head(20)
# Out:
#             STATION Day_Type        TRAFFIC
# 0              1 AV  Weekday   34510.297222
# 1              1 AV  Weekend   11684.388889
# 2            103 ST  Weekday   48761.161905
# 3            103 ST  Weekend   27598.333333
# 4     103 ST-CORONA  Weekday   34081.658333
# 5     103 ST-CORONA  Weekend   23233.500000
# 6            104 ST  Weekday    6013.859524
# 7            104 ST  Weekend    2266.111111
# 8            110 ST  Weekday   18904.488889
# 9            110 ST  Weekend   12210.166667
# 10           111 ST  Weekday   24745.980952
# 11           111 ST  Weekend   16371.888889
# 12           116 ST  Weekday   48764.126984
# 13           116 ST  Weekend   29607.777778
# 14  116 ST-COLUMBIA  Weekday   20686.678968
# 15  116 ST-COLUMBIA  Weekend    6879.722222
# 16           121 ST  Weekday    3688.698016
# 17           121 ST  Weekend    1262.222222
# 18           125 ST  Weekday  137092.174206
# 19           125 ST  Weekend   94562.666667

# %% [markdown]
# ------------

# %% [markdown]
# <font size="5">**By Time of Day**

# %%
def convertTimeBuckets(time):
    
    """
    This function creates a new column that groups time intervals into categories:
    
    00:00 < late night <= 4:00
    4:00 < early risers <= 8:00
    8:00 < morning <= 12:00
    12:00 < afternoon <= 16:00
    16:00 < evening  <= 20:00
    20:00 < late night <= 00:00
    """
    
    hour = time.hour
    if hour > 20 or hour == 0:
        category = 'Late Night'
    elif hour > 16:
        category = 'Evening'
    elif hour > 12:
        category = 'Afternoon'
    elif hour > 8:
        category = 'Morning'
    elif hour > 4:
        category = 'Early Morning'
    elif hour > 0:
        category = 'Late Night'
    
    return category

# %%
df_turns['Day_Bucket'] = df_turns['TIME'].apply(convertTimeBuckets)
df_turns['Day_Type'] = df_turns['Weekday'].apply(daytype)
df_turns['Day_Bucket'] = pd.Categorical(df_turns['Day_Bucket'], categories=
    ['Early Morning','Morning','Afternoon','Evening','Late Night'],
    ordered=True)

# %%
df_buckets_grouped = df_turns.groupby(['STATION','Day_Bucket','Day_Type'])['Total_Traffic'].mean().reset_index()
df_buckets_grouped['Plot_Index']=df_buckets_grouped['Day_Bucket'].apply(indexfun)
df_buckets_grouped['Day_Bucket'] = pd.Categorical(df_buckets_grouped['Day_Bucket'], categories=
    ['Early Morning','Morning','Afternoon','Evening','Late Night'],
    ordered=True)
df_buckets_grouped.head(10)
# Out:
#   STATION     Day_Bucket Day_Type  Total_Traffic Plot_Index
# 0    1 AV  Early Morning  Weekday     376.502128          1
# 1    1 AV  Early Morning  Weekend      49.766667          1
# 2    1 AV        Morning  Weekday     855.386667          2
# 3    1 AV        Morning  Weekend     144.711111          2
# 4    1 AV      Afternoon  Weekday     729.444444          3
# 5    1 AV      Afternoon  Weekend     268.783333          3
# 6    1 AV        Evening  Weekday    1122.357778          4
# 7    1 AV        Evening  Weekend     222.833333          4
# 8    1 AV     Late Night  Weekday     197.621111          0
# 9    1 AV     Late Night  Weekend     209.862857          0

# %%
daytime = ['Late Night','Early Morning', 'Morning', 'Afternoon','Evening']
def indexfun(bucket):
    if bucket == 'Late Night':
        return 0
    if bucket == 'Early Morning':
        return 1
    if bucket == 'Morning':
        return 2
    if bucket == 'Afternoon':
        return 3
    if bucket == 'Evening':
        return 4
df_buckets_grouped['Plot_Index']=df_buckets_grouped['Day_Bucket'].apply(indexfun)

#Anthony's category shift

df_buckets_grouped['Day_Bucket'] = pd.Categorical(df_buckets_grouped['Day_Bucket'], categories=
    ['Early Morning','Morning','Afternoon','Evening','Late Night'],
    ordered=True)
df_buckets_grouped.head(10)
# Out:
#   STATION     Day_Bucket Day_Type  Total_Traffic Plot_Index
# 0    1 AV  Early Morning  Weekday     376.502128          1
# 1    1 AV  Early Morning  Weekend      49.766667          1
# 2    1 AV        Morning  Weekday     855.386667          2
# 3    1 AV        Morning  Weekend     144.711111          2
# 4    1 AV      Afternoon  Weekday     729.444444          3
# 5    1 AV      Afternoon  Weekend     268.783333          3
# 6    1 AV        Evening  Weekday    1122.357778          4
# 7    1 AV        Evening  Weekend     222.833333          4
# 8    1 AV     Late Night  Weekday     197.621111          0
# 9    1 AV     Late Night  Weekend     209.862857          0

# %%
df_buckets_weekday = df_buckets_grouped[df_buckets_grouped['Day_Type'] == 'Weekday']
df_buckets_weekend = df_buckets_grouped[df_buckets_grouped['Day_Type'] == 'Weekend']

# %%
# Grand Central 42nd street is a problem

df_buckets_weekday[df_buckets_weekday['STATION'] == 'GRD CNTRL-42 ST']
# Out:
#               STATION     Day_Bucket Day_Type  Total_Traffic Plot_Index
# 2320  GRD CNTRL-42 ST  Early Morning  Weekday     232.333333          1
# 2322  GRD CNTRL-42 ST        Morning  Weekday    3152.470686          2
# 2324  GRD CNTRL-42 ST      Afternoon  Weekday  425826.634514          3
# 2326  GRD CNTRL-42 ST        Evening  Weekday    1625.233277          4
# 2328  GRD CNTRL-42 ST     Late Night  Weekday    2766.791597          0

# %%
df_buckets_weekday['Day_Bucket'] = pd.Categorical(df_buckets_weekday['Day_Bucket'], categories=
    ['Early Morning','Morning','Afternoon','Evening','Late Night'],
    ordered=True)
df_buckets_weekday
# Out:
# /Users/lewissears/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
#         STATION     Day_Bucket Day_Type  Total_Traffic Plot_Index
# 0          1 AV  Early Morning  Weekday     376.502128          1
# 2          1 AV        Morning  Weekday     855.386667          2
# 4          1 AV      Afternoon  Weekday     729.444444          3
# 6          1 AV        Evening  Weekday    1122.357778          4
# 8          1 AV     Late Night  Weekday     197.621111          0
# ...         ...            ...      ...            ...        ...
# 3770  ZEREGA AV  Early Morning  Weekday      22.900000          1
# 3772  ZEREGA AV        Morning  Weekday     255.777778          2
# 3774  ZEREGA AV      Afternoon  Weekday     138.692593          3
# 3776  ZEREGA AV        Evening  Weekday     190.596296          4
# 3778  ZEREGA AV     Late Night  Weekday     115.087037          0
#
# [1890 rows x 5 columns]

# %%
sums = df_buckets_grouped.groupby(['STATION']).sum()
top_30 = sums['Total_Traffic'].nlargest(30)
top_30
# Out:
# STATION
# CYPRESS AV         2.641197e+07
# HUNTS POINT AV     7.026393e+06
# LAFAYETTE AV       5.059442e+06
# 3 AV-149 ST        3.520996e+06
# 72 ST              3.491998e+06
# 5 AVE              3.418172e+06
# 161/YANKEE STAD    1.566737e+06
# 14 ST              1.561882e+06
# 59 ST              1.180548e+06
# 51 ST              1.125224e+06
# BAY PKWY           9.475492e+05
# GRD CNTRL-42 ST    4.358490e+05
# 18 ST              2.991713e+05
# ROCKAWAY BLVD      2.911962e+05
# NECK RD            2.707720e+05
# SOUTH FERRY        2.397750e+05
# LIVONIA AV         1.523451e+05
# 191 ST             1.272162e+05
# BOROUGH HALL       1.269776e+05
# NEW LOTS           1.244737e+05
# 157 ST             8.484784e+04
# 49 ST              7.795557e+04
# PARSONS BLVD       6.222548e+04
# JEFFERSON ST       5.798689e+04
# FORDHAM RD         4.950591e+04
# BAY RIDGE AV       3.012301e+04
# WEST FARMS SQ      2.931465e+04
# HOUSTON ST         2.695057e+04
# FULTON ST          2.579110e+04
# ROCKAWAY AV        2.385432e+04
# Name: Total_Traffic, dtype: float64

# %%
#Busy Stations during Weekdays

plt.figure(figsize=(10,5))
for station in ['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']:
    plt.plot(df_buckets_weekday[df_buckets_weekday['STATION'] == station]['Day_Bucket'],df_buckets_weekday[df_buckets_weekday['STATION'] == station]['Total_Traffic'])

plt.title('Weekday Mean Traffic',fontsize = 15,weight='bold',color='Blue')
plt.legend(['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']);
plt.savefig('Weekday_Traffic.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-d727348311f8> in <module>
#       1 #Busy Stations during Weekdays
#       2
# ----> 3 plt.figure(figsize=(10,5))
#       4 for station in ['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']:
#       5     plt.plot(df_buckets_weekday[df_buckets_weekday['STATION'] == station]['Day_Bucket'],df_buckets_weekday[df_buckets_weekday['STATION'] == station]['Total_Traffic'])
#
# NameError: name 'plt' is not defined

# %%
#Busy Stations During Weekends

plt.figure(figsize=(10,5))
for station in ['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']:
    plt.plot(df_buckets_weekend[df_buckets_weekend['STATION'] == station]['Day_Bucket'],df_buckets_weekend[df_buckets_weekend['STATION'] == station]['Total_Traffic'])

plt.title('Weekend Mean Traffic',fontsize = 15,weight='bold',color='Blue')
plt.legend(['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']);
plt.savefig('Weekend_Traffic.png')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-d73f01c8df02> in <module>
#       1 #Busy Stations During Weekends
#       2
# ----> 3 plt.figure(figsize=(10,5))
#       4 for station in ['34 ST-PENN STA', '34 ST-HERALD SQ', 'TIMES SQ-42 ST', '23 ST', '42 ST-PORT AUTH', '86 ST']:
#       5     plt.plot(df_buckets_weekend[df_buckets_weekend['STATION'] == station]['Day_Bucket'],df_buckets_weekend[df_buckets_weekend['STATION'] == station]['Total_Traffic'])
#
# NameError: name 'plt' is not defined

# %%
df_buckets_weekday[df_buckets_weekday['Day_Bucket'] == 'Afternoon'].sort_values('Total_Traffic', ascending = False)
# Out:
#               STATION Day_Bucket Day_Type  Total_Traffic Plot_Index
# 2684     LAFAYETTE AV  Afternoon  Weekday   5.058636e+06          3
# 554       3 AV-149 ST  Afternoon  Weekday   3.518721e+06          3
# 774             5 AVE  Afternoon  Weekday   3.415378e+06          3
# 134             14 ST  Afternoon  Weekday   1.559127e+06          3
# 1364         BAY PKWY  Afternoon  Weekday   9.458698e+05          3
# 2324  GRD CNTRL-42 ST  Afternoon  Weekday   4.258266e+05          3
# 324             18 ST  Afternoon  Weekday   2.974164e+05          3
# 3314    ROCKAWAY BLVD  Afternoon  Weekday   2.899026e+05          3
# 3404      SOUTH FERRY  Afternoon  Weekday   2.383079e+05          3
# 2944         NEW LOTS  Afternoon  Weekday   1.213651e+05          3
# 204            157 ST  Afternoon  Weekday   8.231997e+04          3
# 3134     PARSONS BLVD  Afternoon  Weekday   6.076506e+04          3
# 2544     JEFFERSON ST  Afternoon  Weekday   5.480174e+04          3
# 2174       FORDHAM RD  Afternoon  Weekday   4.703228e+04          3
# 2414       HOUSTON ST  Afternoon  Weekday   2.567277e+04          3
# 3304      ROCKAWAY AV  Afternoon  Weekday   2.210640e+04          3
# 974             72 ST  Afternoon  Weekday   1.461850e+04          3
# 334            181 ST  Afternoon  Weekday   1.286804e+04          3
# 1984        DEKALB AV  Afternoon  Weekday   8.375317e+03          3
# 2064    EAST BROADWAY  Afternoon  Weekday   6.963026e+03          3
# 724    47-50 STS ROCK  Afternoon  Weekday   3.622168e+03          3
# 1494  BEDFORD PK BLVD  Afternoon  Weekday   3.440850e+03          3
# 1484       BEDFORD AV  Afternoon  Weekday   3.112337e+03          3
# 3284    RIT-MANHATTAN  Afternoon  Weekday   2.948289e+03          3
# 3154       PATH WTC 2  Afternoon  Weekday   2.723761e+03          3
# 1564   BOTANIC GARDEN  Afternoon  Weekday   2.615439e+03          3
# 2254        FULTON ST  Afternoon  Weekday   2.582834e+03          3
# 3744  WORLD TRADE CTR  Afternoon  Weekday   2.454407e+03          3
# 914     66 ST-LINCOLN  Afternoon  Weekday   2.174816e+03          3
# 144    14 ST-UNION SQ  Afternoon  Weekday   1.742385e+03          3
# 3764          YORK ST  Afternoon  Weekday   1.425704e+03          3
# 1544      BLEECKER ST  Afternoon  Weekday   1.046546e+03          3
# 2574   JOURNAL SQUARE  Afternoon  Weekday   1.037264e+03          3
# 2864        MYRTLE AV  Afternoon  Weekday   9.797833e+02          3
# 2444       HOYT-SCHER  Afternoon  Weekday   9.749733e+02          3
# 2554  JFK JAMAICA CT1  Afternoon  Weekday   9.047955e+02          3
# 2704  LEXINGTON AV/63  Afternoon  Weekday   4.666129e+02          3
# 1794      CHAMBERS ST  Afternoon  Weekday   4.661598e+02          3
# 1644     BROADWAY JCT  Afternoon  Weekday   4.635860e+02          3
# 784             50 ST  Afternoon  Weekday   4.629148e+02          3
# 3234    PROSPECT PARK  Afternoon  Weekday   4.627972e+02          3
# 1954  CROWN HTS-UTICA  Afternoon  Weekday   4.612370e+02          3
# 1634         BROADWAY  Afternoon  Weekday   4.603846e+02          3
# 2374    HARLEM 148 ST  Afternoon  Weekday   4.592296e+02          3
# 64             116 ST  Afternoon  Weekday   4.583182e+02          3
# 884    61 ST WOODSIDE  Afternoon  Weekday   4.582323e+02          3
# 2694  LEXINGTON AV/53  Afternoon  Weekday   4.563657e+02          3
# 2934        NEVINS ST  Afternoon  Weekday   4.560156e+02          3
# 2284  GRAND ARMY PLAZ  Afternoon  Weekday   4.538000e+02          3
# 3584   V.CORTLANDT PK  Afternoon  Weekday   4.514091e+02          3
# 1874     CLEVELAND ST  Afternoon  Weekday   4.510556e+02          3
# 304            176 ST  Afternoon  Weekday   4.506667e+02          3
# 2534  JAY ST-METROTEC  Afternoon  Weekday   4.465733e+02          3
# 3144     PATH NEW WTC  Afternoon  Weekday   4.463573e+02          3
# 584   33 ST-RAWSON ST  Afternoon  Weekday   4.448333e+02          3
# 1994   DELANCEY/ESSEX  Afternoon  Weekday   4.437835e+02          3
# 1054         8 ST-NYU  Afternoon  Weekday   4.435788e+02          3
# 3494  SUTTER AV-RUTLD  Afternoon  Weekday   4.432154e+02          3
# 3614   VERNON-JACKSON  Afternoon  Weekday   4.425636e+02          3
# 344       182-183 STS  Afternoon  Weekday   4.382074e+02          3
# 2304    GRAND-NEWTOWN  Afternoon  Weekday   4.378259e+02          3
# 3264         RALPH AV  Afternoon  Weekday   4.358864e+02          3
# 1854         CLARK ST  Afternoon  Weekday   4.295167e+02          3
# 354            183 ST  Afternoon  Weekday   4.284722e+02          3
# 3454      STERLING ST  Afternoon  Weekday   4.270519e+02          3
# 2654    KNICKERBOCKER  Afternoon  Weekday   4.267611e+02          3
# 1194      ALLERTON AV  Afternoon  Weekday   4.251014e+02          3
# 2014       DYCKMAN ST  Afternoon  Weekday   4.200370e+02          3
# 1584    BOWLING GREEN  Afternoon  Weekday   4.193196e+02          3
# 2854       MT EDEN AV  Afternoon  Weekday   4.184222e+02          3
# 2184       FOREST AVE  Afternoon  Weekday   4.175630e+02          3
# 2274        GRAHAM AV  Afternoon  Weekday   4.140507e+02          3
# 1764   CATHEDRAL PKWY  Afternoon  Weekday   4.097551e+02          3
# 3574         UTICA AV  Afternoon  Weekday   4.089179e+02          3
# 2884   MYRTLE-WYCKOFF  Afternoon  Weekday   4.079475e+02          3
# 1034            79 ST  Afternoon  Weekday   4.070825e+02          3
# 1834       CITY / BUS  Afternoon  Weekday   4.058354e+02          3
# 2604      KEW GARDENS  Afternoon  Weekday   4.048606e+02          3
# 1934   COURT SQ-23 ST  Afternoon  Weekday   4.013207e+02          3
# 3714      WINTHROP ST  Afternoon  Weekday   3.998722e+02          3
# 474            231 ST  Afternoon  Weekday   2.092778e+02          3
# 3104       PARK PLACE  Afternoon  Weekday   2.082222e+02          3
# 964             71 ST  Afternoon  Weekday   2.078957e+02          3
# 3094  OZONE PK LEFFRT  Afternoon  Weekday   2.046545e+02          3
# 924             67 AV  Afternoon  Weekday   2.042423e+02          3
# 2244  FT HAMILTON PKY  Afternoon  Weekday   2.007767e+02          3
# 254            169 ST  Afternoon  Weekday   1.998711e+02          3
# 2124   EXCHANGE PLACE  Afternoon  Weekday   1.956842e+02          3
# 1914     CORTLANDT ST  Afternoon  Weekday   1.937622e+02          3
# 2674       LACKAWANNA  Afternoon  Weekday   1.936926e+02          3
# 2834      MORRIS PARK  Afternoon  Weekday   1.932444e+02          3
# 1884  CLINTON-WASH AV  Afternoon  Weekday   1.926398e+02          3
# 1324         AVENUE U  Afternoon  Weekday   1.913221e+02          3
# 704             46 ST  Afternoon  Weekday   1.910456e+02          3
# 1314         AVENUE P  Afternoon  Weekday   1.888593e+02          3
# 1654  BRONX PARK EAST  Afternoon  Weekday   1.884667e+02          3
# 284       174-175 STS  Afternoon  Weekday   1.857333e+02          3
# 2724       LIVONIA AV  Afternoon  Weekday   1.803022e+02          3
# 2454    HUNTERS PT AV  Afternoon  Weekday   1.752956e+02          3
# 224   163 ST-AMSTERDM  Afternoon  Weekday   1.746806e+02          3
# 1384  BAY RIDGE-95 ST  Afternoon  Weekday   1.734442e+02          3
# 1294         AVENUE M  Afternoon  Weekday   1.731244e+02          3
# 2734      LONGWOOD AV  Afternoon  Weekday   1.728297e+02          3
# 2504   JAMAICA 179 ST  Afternoon  Weekday   1.722037e+02          3
# 3504        THIRTY ST  Afternoon  Weekday   1.720508e+02          3
# 3074       OCEAN PKWY  Afternoon  Weekday   1.705778e+02          3
# 1684         BUHRE AV  Afternoon  Weekday   1.698667e+02          3
# 2394         HEWES ST  Afternoon  Weekday   1.664063e+02          3
# 644             39 AV  Afternoon  Weekday   1.636333e+02          3
# 2964   NEW UTRECHT AV  Afternoon  Weekday   1.627278e+02          3
# 1454      BEACH 67 ST  Afternoon  Weekday   1.625289e+02          3
# 1964       CYPRESS AV  Afternoon  Weekday   1.583883e+02          3
# 3754    WTC-CORTLANDT  Afternoon  Weekday   1.573409e+02          3
# 3294    RIT-ROOSEVELT  Afternoon  Weekday   1.573074e+02          3
# 1594        BRIARWOOD  Afternoon  Weekday   1.534750e+02          3
# 1624         BROAD ST  Afternoon  Weekday   1.516308e+02          3
# 434            215 ST  Afternoon  Weekday   1.516056e+02          3
# 184    15 ST-PROSPECT  Afternoon  Weekday   1.505537e+02          3
# 1064            80 ST  Afternoon  Weekday   1.492159e+02          3
# 1974    CYPRESS HILLS  Afternoon  Weekday   1.422296e+02          3
# 1254      ATLANTIC AV  Afternoon  Weekday   1.415379e+02          3
# 2004        DITMAS AV  Afternoon  Weekday   1.413260e+02          3
# 494            238 ST  Afternoon  Weekday   1.400652e+02          3
# 3464     SUTPHIN BLVD  Afternoon  Weekday   1.400267e+02          3
# 3774        ZEREGA AV  Afternoon  Weekday   1.386926e+02          3
# 1284         AVENUE J  Afternoon  Weekday   1.347568e+02          3
# 3694      WHITLOCK AV  Afternoon  Weekday   1.296022e+02          3
# 1444      BEACH 60 ST  Afternoon  Weekday   1.269111e+02          3
# 2994     NEWARK HM HE  Afternoon  Weekday   1.253143e+02          3
# 2904          NECK RD  Afternoon  Weekday   1.242571e+02          3
# 2914       NEPTUNE AV  Afternoon  Weekday   1.224074e+02          3
# 2424   HOWARD BCH JFK  Afternoon  Weekday   1.125370e+02          3
# 34             104 ST  Afternoon  Weekday   1.115827e+02          3
# 1414      BEACH 25 ST  Afternoon  Weekday   1.079600e+02          3
# 84             121 ST  Afternoon  Weekday   1.068767e+02          3
# 1304         AVENUE N  Afternoon  Weekday   1.066635e+02          3
# 1274         AVENUE I  Afternoon  Weekday   9.590411e+01          3
# 1204  AQUEDUCT N.COND  Afternoon  Weekday   9.464889e+01          3
# 1464      BEACH 90 ST  Afternoon  Weekday   8.399556e+01          3
# 2794    MIDDLETOWN RD  Afternoon  Weekday   8.348889e+01          3
# 2384         HARRISON  Afternoon  Weekday   7.617334e+01          3
# 1004            75 AV  Afternoon  Weekday   7.440000e+01          3
# 1214  AQUEDUCT RACETR  Afternoon  Weekday   7.009091e+01          3
# 3004  NEWARK HW BMEBE  Afternoon  Weekday   6.677519e+01          3
# 1424      BEACH 36 ST  Afternoon  Weekday   6.430000e+01          3
# 3434       ST. GEORGE  Afternoon  Weekday   6.244678e+01          3
# 3324  ROCKAWAY PARK B  Afternoon  Weekday   5.539111e+01          3
# 1434      BEACH 44 ST  Afternoon  Weekday   5.322273e+01          3
# 2784  METS-WILLETS PT  Afternoon  Weekday   5.320317e+01          3
# 2024  E 143/ST MARY'S  Afternoon  Weekday   5.272783e+01          3
# 2984         NEWARK C  Afternoon  Weekday   4.541268e+01          3
# 1474      BEACH 98 ST  Afternoon  Weekday   2.968182e+01          3
# 1614    BROAD CHANNEL  Afternoon  Weekday   1.967407e+01          3
# 3534    TOMPKINSVILLE  Afternoon  Weekday   1.725397e+01          3
# 1404     BEACH 105 ST  Afternoon  Weekday   1.555556e+01          3
# 3084    ORCHARD BEACH  Afternoon  Weekday   5.450000e-01          3

# %%
df_buckets_weekend
# Out:
#         STATION     Day_Bucket Day_Type  Total_Traffic Plot_Index
# 1          1 AV  Early Morning  Weekend      49.766667          1
# 3          1 AV        Morning  Weekend     144.711111          2
# 5          1 AV      Afternoon  Weekend     268.783333          3
# 7          1 AV        Evening  Weekend     222.833333          4
# 9          1 AV     Late Night  Weekend     209.862857          0
# ...         ...            ...      ...            ...        ...
# 3771  ZEREGA AV  Early Morning  Weekend      18.259259          1
# 3773  ZEREGA AV        Morning  Weekend      53.240741          2
# 3775  ZEREGA AV      Afternoon  Weekend      70.970588          3
# 3777  ZEREGA AV        Evening  Weekend      93.740741          4
# 3779  ZEREGA AV     Late Night  Weekend      63.900000          0
#
# [1890 rows x 5 columns]

# %%
df_buckets_weekend
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-196f72168619> in <module>
# ----> 1 df_buckets_weekend
#
# NameError: name 'df_buckets_weekend' is not defined
